# %% [markdown]
# # Initial Exploratory Data Analysis

# %% [markdown]
# ### Quick explanation of project
# - Goal:
# - Dataset:
# - Features:
# - Models used:

# %% [markdown]
# ### Importing dataset and Overview

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load fraud detection dataset
data = pd.read_csv('../Raw Data /train.csv')
data = pd.DataFrame(data)
data.head(10)
# Out:
#    Unnamed: 0           artist_name  \
# 0           0                mukesh
# 1           4         frankie laine
# 2           6           johnnie ray
# 3          10           pérez prado
# 4          12  giorgos papadopoulos
# 5          14            perry como
# 6          15             freestyle
# 7          17         johnny mathis
# 8          20   stélios kazantzídis
# 9          23   stélios kazantzídis
#
#                                           track_name  release_date genre  \
# 0                               mohabbat bhi jhoothi          1950   pop
# 1                                          i believe          1950   pop
# 2                                                cry          1950   pop
# 3                                           patricia          1950   pop
# 4                                 apopse eida oneiro          1950   pop
# 5  round and round (with mitchell ayres and his o...          1950   pop
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28362 entries, 0 to 28361
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28362 non-null  int64
#  1   artist_name               28362 non-null  object
#  2   track_name                28362 non-null  object
#  3   release_date              28362 non-null  int64
#  4   genre                     28362 non-null  object
#  5   lyrics                    28362 non-null  object
#  6   len                       28362 non-null  int64
#  7   dating                    28362 non-null  float64
#  8   violence                  28362 non-null  float64
#  9   world/life                28362 non-null  float64
#  10  night/time                28362 non-null  float64
#  11  shake the audience        28362 non-null  float64
#  12  family/gospel             28362 non-null  float64
# ...

# %% [markdown]
# Data appears to have no non-null values however a deeper look may show some patterns of non obvious null values. During importing, the dataset has included a new column that appears to be an index column. This is not necessary so it will be dropped.

# %%
data.describe()
# Out:
#          Unnamed: 0  release_date           len        dating      violence  \
# count  28362.000000  28362.000000  28362.000000  28362.000000  28362.000000
# mean   42948.166878   1990.239652     73.030534      0.021110      0.118371
# std    24747.811462     18.486997     41.831605      0.052366      0.178658
# min        0.000000   1950.000000      1.000000      0.000291      0.000284
# 25%    20393.500000   1975.000000     42.000000      0.000923      0.001120
# 50%    45407.000000   1991.000000     63.000000      0.001462      0.002506
# 75%    64089.500000   2007.000000     93.000000      0.004049      0.192538
# max    82451.000000   2019.000000    199.000000      0.647706      0.981781
#
#          world/life    night/time  shake the audience  family/gospel  \
# count  28362.000000  28362.000000        28362.000000   28362.000000
# mean       0.120984      0.057356            0.017418       0.017045
# std        0.172216      0.111892            0.040658       0.041968
# ...

# %%
numeric_cols = data.select_dtypes(include='number').columns

for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(data[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data[numeric_cols].corr(), annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Insights from correlation map:
# - Release date & age have a perfect negative correlation (one can be dropped since they both reference eachother)
# - Len and obscene - 0.44 positive correlation- not sure if this is important but perhaps length of a song is related to certain genres (less words could equal more instrumentals or vice versa, this could be explored more)

# %% [markdown]
# Aside from cleaning the data, a more targetted correlation matrix could provide insights on how similiar certain songs are based on themes. This can help with clearer reccomendations that don't rely on simply giving a user similiar songs based on one genre or one theme.
# - Groups of thematic content could potentially be made as new columns

# %%
thematic_cols = ['dating', 'violence', 'world/life', 'night/time', 'shake the audience',
                 'family/gospel', 'romantic', 'communication', 'obscene', 'music',
                 'movement/places', 'light/visual perceptions', 'family/spiritual',
                 'sadness', 'feelings']  

plt.figure(figsize=(12, 10))
sns.heatmap(data[thematic_cols].corr(), annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap - Thematic Features')
plt.show()

# %%
plt.figure(figsize=(12, 10))  # Set the figure size BEFORE plotting
sns.heatmap(data[thematic_cols].corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Theme Correlation Heatmap")
plt.show()

# %%
# Top 10 themes by total score
top_themes = data[thematic_cols].sum().sort_values(ascending=False).head(10).index

# Using total scores of the top themes - sum of each theme across all songs
plt.figure(figsize=(12, 6))
data[top_themes].sum().sort_values(ascending=True).plot(kind='barh', color='skyblue')
plt.title('Top 10 Themes Across Lyrics')
plt.xlabel('Total Theme Score Across All Songs')
plt.ylabel('Song Theme')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Additional Data to compare:
# - Age of songs compared to each theme (determines how age impacts the themes- this could determine whether a specific type of user might be recomended more **older** or **newer** songs on average)
#
# - Score thresholds: What is the average threshod for the scores
# - [Add note] on top themes, there true top are sadness, world/life and violence- how are these clustered together?  Deeper dive into lyrics?
#
# **To note:** What constitutes as newness or oldness of a song? This might need to be added as a new column with a specific range (E.g: "age" <5 for a newer song- In other terms, a song that is younger than 5 years old might be considered modern. This scale can be broken up into more parts for better specificicty)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# From the above initial EDA, a few cleaning tasks seem most important before diving into the data deeper:
# - Dropping unecessary coloumns

# %%
data = data.drop(columns=['Unnamed: 0', 'release_date'])
data.to_csv("music_data.csv", index=False)

# %%
data.head()
# Out:
#             artist_name            track_name genre  \
# 0                mukesh  mohabbat bhi jhoothi   pop
# 1         frankie laine             i believe   pop
# 2           johnnie ray                   cry   pop
# 3           pérez prado              patricia   pop
# 4  giorgos papadopoulos    apopse eida oneiro   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
#    world/life  night/time  shake the audience  ...  communication   obscene  \
# 0    0.000598    0.000598            0.000598  ...       0.263751  0.000598
# ...
