# %% [markdown]
# # Music Reccomendation Report

# %% [markdown]
# ### Insights from Exploratory Data Analysis (EDA)
# Key findings from EDA: <br>
# - Note any themes or columns that were significantly correlated and describe the nature of these relationships.
# <br>
# <br>

# %% [markdown]
# ### Feature Selection Process
# - Explain your rationale for keeping or removing certain columns. Describe how your EDA guided these decisions and what patterns or redundancies informed your selections.
# <br>
# <br>

# %% [markdown]
# ### Determining the Optimal Number of Clusters
# **Optimal Number of Clusters**: 14 <br>
# - Describe the method used (e.g., Elbow Method, Silhouette Score) and justify why this number was chosen.
# <br>
# <br>

# %% [markdown]
# ### Interpretation of Clusters
# Characteristics of each cluster using the thematic variables in the dataset:
# - Where possible, assign intuitive or human-readable labels (e.g., "high-romance, low-obscenity" or "high-energy, spiritual songs").
# - Reference specific songs in each cluster to support your interpretation.

# %% [markdown]
# ### Song Recommendations Based on Cluster Assignments
# - Discuss the songs that your model assigned to each cluster and how this informs personalized recommendations. Use the test samples to suggest songs a user might enjoy, based on the cluster they belong to and the defining features of that group.
